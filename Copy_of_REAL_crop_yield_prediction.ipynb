# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")

# %%
import zipfile
import os

# List files in the current directory to check if the ZIP file exists
print(os.listdir())

# Adjust the path if the ZIP file is located elsewhere
zip_file_path = "yield_df.csv.zip"  # Update with the correct path if needed

# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall()  # Extracts all contents to the current directory

print("File unzipped successfully!")
# Out:
# ['.config', 'yield_df.csv.zip', 'sample_data']
# File unzipped successfully!

# %%
df = pd.read_csv("yield_df.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     Area         Item  Year  hg/ha_yield  \
# 0           0  Albania        Maize  1990        36613
# 1           1  Albania     Potatoes  1990        66667
# 2           2  Albania  Rice, paddy  1990        23333
# 3           3  Albania      Sorghum  1990        12500
# 4           4  Albania     Soybeans  1990         7000
#
#    average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                         1485.0              121.0     16.37
# 1                         1485.0              121.0     16.37
# 2                         1485.0              121.0     16.37
# 3                         1485.0              121.0     16.37
# 4                         1485.0              121.0     16.37

# %%
df.drop('Unnamed: 0',axis=1, inplace=True)

# %%
df.head()
# Out:
#       Area         Item  Year  hg/ha_yield  average_rain_fall_mm_per_year  \
# 0  Albania        Maize  1990        36613                         1485.0
# 1  Albania     Potatoes  1990        66667                         1485.0
# 2  Albania  Rice, paddy  1990        23333                         1485.0
# 3  Albania      Sorghum  1990        12500                         1485.0
# 4  Albania     Soybeans  1990         7000                         1485.0
#
#    pesticides_tonnes  avg_temp
# 0              121.0     16.37
# 1              121.0     16.37
# 2              121.0     16.37
# 3              121.0     16.37
# 4              121.0     16.37

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28242 entries, 0 to 28241
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Area                           28242 non-null  object
#  1   Item                           28242 non-null  object
#  2   Year                           28242 non-null  int64
#  3   hg/ha_yield                    28242 non-null  int64
#  4   average_rain_fall_mm_per_year  28242 non-null  float64
#  5   pesticides_tonnes              28242 non-null  float64
#  6   avg_temp                       28242 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 1.5+ MB

# %%
df.isnull().sum()
# Out:
# Area                             0
# Item                             0
# Year                             0
# hg/ha_yield                      0
# average_rain_fall_mm_per_year    0
# pesticides_tonnes                0
# avg_temp                         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 2310

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (25932, 7)

# %%
df.describe()
# Out:
#                Year    hg/ha_yield  average_rain_fall_mm_per_year  \
# count  25932.000000   25932.000000                   25932.000000
# mean    2001.556455   76978.132925                    1146.836688
# std        7.055924   84647.605552                     717.391098
# min     1990.000000      50.000000                      51.000000
# 25%     1995.000000   19996.000000                     593.000000
# 50%     2001.000000   39530.000000                    1083.000000
# 75%     2008.000000  104168.000000                    1668.000000
# max     2013.000000  501412.000000                    3240.000000
#
#        pesticides_tonnes      avg_temp
# count       25932.000000  25932.000000
# mean        34782.573241     20.422251
# std         57228.568244      6.439402
# min             0.040000      1.300000
# 25%          1597.000000     16.580000
# 50%         15373.000000     21.420000
# 75%         45620.000000     26.060000
# max        367778.000000     30.650000

# %%
#data visualisation

# %%
len(df['Area'].unique())
# Out:
# 101

# %%
df.head()
# Out:
#       Area         Item  Year  hg/ha_yield  average_rain_fall_mm_per_year  \
# 0  Albania        Maize  1990        36613                         1485.0
# 1  Albania     Potatoes  1990        66667                         1485.0
# 2  Albania  Rice, paddy  1990        23333                         1485.0
# 3  Albania      Sorghum  1990        12500                         1485.0
# 4  Albania     Soybeans  1990         7000                         1485.0
#
#    pesticides_tonnes  avg_temp
# 0              121.0     16.37
# 1              121.0     16.37
# 2              121.0     16.37
# 3              121.0     16.37
# 4              121.0     16.37

# %%
df.shape
# Out:
# (25932, 7)

# %%
len(df['Item'].unique())
# Out:
# 10

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,20))
sns.countplot(y = df['Area'])
plt.show()

# %%
plt.figure(figsize=(15,20))
sns.countplot(y = df['Item'])
plt.show()

# %%
(df['Area'].value_counts() <400).sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of Area
# India         False
# Brazil        False
# Mexico        False
# Australia     False
# Pakistan      False
#               ...
# Estonia        True
# Belgium        True
# Bahrain        True
# Sudan          True
# Montenegro     True
# Name: count, Length: 101, dtype: bool>

# %%
# Fix the indentation of the line causing the error
countries = df['Area'].unique()
yield_per_country = []
for country in countries:
    yield_per_country.append(df[df['Area'] == country]['hg/ha_yield'].sum())

# %%
df['hg/ha_yield'].sum()
# Out:
# 1996196943

# %%
yield_per_country
# Out:
# [5711536,
#  6711464,
#  5722563,
#  32864032,
#  4524100,
#  109111062,
#  10852258,
#  4608380,
#  4384717,
#  4443889,
#  7720159,
#  4704812,
#  8442270,
#  470651,
#  136340329,
#  6263075,
#  6083337,
#  7031146,
#  10717883,
#  34706922,
#  4255627,
#  20561214,
#  26927138,
#  6083167,
#  10701651,
#  25312166,
#  21315591,
#  36828848,
#  16855944,
#  1452416,
#  3595638,
#  6210668,
#  15790618,
#  38780463,
#  9260371,
#  14571925,
#  16508723,
#  7975743,
#  8361103,
#  8619194,
#  10920131,
#  8824110,
#  274219558,
#  68067328,
#  10984722,
#  9104030,
#  32280700,
#  19698007,
#  100924145,
#  9965212,
#  14391737,
#  3698588,
#  6956804,
#  4258932,
#  9016288,
#  4174348,
#  6103523,
#  8346715,
#  7934982,
#  15106720,
#  4465841,
#  12684212,
#  113698872,
#  1645100,
#  22173010,
#  6964027,
#  3165475,
#  4113713,
#  14086433,
#  17657728,
#  12819227,
#  12316327,
#  6721305,
#  49264956,
#  10729929,
#  15201910,
#  6564711,
#  12154347,
#  5995626,
# ...

# %%
# Create a DataFrame with two columns: "country" and "yield_per_country"
df_yield = pd.DataFrame({
    "country": countries,
    "yield_per_country": yield_per_country
})

# Plot the bar chart using the DataFrame
plt.figure(figsize=(15, 20))
sns.barplot(data=df_yield, y="country", x="yield_per_country")
plt.show()

# %%
# Fix the indentation of the line causing the error
crops = df['Item'].unique()
yield_per_crop = []
for crop in crops:
    yield_per_crop.append(df[df['Item'] == crop]['hg/ha_yield'].sum())

df_crop_yield_per_crop = pd.DataFrame({
    "crop": crops,
    "yield_per_crop": yield_per_crop
})

# %%
import seaborn as sns

# %%
plt.figure(figsize=(15,20))
sns.barplot(data=df_crop_yield_per_crop,y="crop", x="yield_per_crop")
plt.show()

# %%
df.plot(kind="bar", x="Item", y="hg/ha_yield")
plt.show()

# %%
df.head()
# Out:
#       Area         Item  Year  hg/ha_yield  average_rain_fall_mm_per_year  \
# 0  Albania        Maize  1990        36613                         1485.0
# 1  Albania     Potatoes  1990        66667                         1485.0
# 2  Albania  Rice, paddy  1990        23333                         1485.0
# 3  Albania      Sorghum  1990        12500                         1485.0
# 4  Albania     Soybeans  1990         7000                         1485.0
#
#    pesticides_tonnes  avg_temp
# 0              121.0     16.37
# 1              121.0     16.37
# 2              121.0     16.37
# 3              121.0     16.37
# 4              121.0     16.37

# %%
df.columns
# Out:
# Index(['Area', 'Item', 'Year', 'hg/ha_yield', 'average_rain_fall_mm_per_year',
#        'pesticides_tonnes', 'avg_temp'],
#       dtype='object')

# %%
col = ['Year','average_rain_fall_mm_per_year','pesticides_tonnes','avg_temp','Area','Item','hg/ha_yield']

# %%
df = df[col]

# %%
df.head()
# Out:
#    Year  average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp     Area  \
# 0  1990                         1485.0              121.0     16.37  Albania
# 1  1990                         1485.0              121.0     16.37  Albania
# 2  1990                         1485.0              121.0     16.37  Albania
# 3  1990                         1485.0              121.0     16.37  Albania
# 4  1990                         1485.0              121.0     16.37  Albania
#
#           Item  hg/ha_yield
# 0        Maize        36613
# 1     Potatoes        66667
# 2  Rice, paddy        23333
# 3      Sorghum        12500
# 4     Soybeans         7000

# %%
X = df.drop('hg/ha_yield', axis = 1)
Y = df['hg/ha_yield']

# %%
X.shape
# Out:
# (25932, 6)

# %%
Y.shape
# Out:
# (25932,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, train_size = 0.7, random_state = 0, shuffle=True)

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
ohe = OneHotEncoder(drop = 'first')
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
scale = StandardScaler()

# Column indices for scaling and encoding
#'Area', 'Item', 'Year', 'hg/ha_yield', 'average_rain_fall_mm_per_year','pesticides_tonnes', 'avg_temp'
scaling_columns = ['Year', 'average_rain_fall_mm_per_year', 'pesticides_tonnes','avg_temp']
encoding_columns = ['Area', 'Item',]

# Define the ColumnTransformer with the appropriate transformers
preprocessor = ColumnTransformer(
    transformers=[
        ('scaler', StandardScaler(), scaling_columns),
        ('encoder', OneHotEncoder(), encoding_columns)
    ]
)

# %%
X_train_dummy = preprocessor.fit_transform(X_train)
X_test_dummy = preprocessor.fit_transform(X_test)

# %%
# Fit the preprocessor object
preprocessor.fit(X)

# Get the transformed feature names
transformed_feature_names = preprocessor.get_feature_names_out()

# (Optional) Print the transformed feature names
print(transformed_feature_names)
# Out:
# ['scaler__Year' 'scaler__average_rain_fall_mm_per_year'
#  'scaler__pesticides_tonnes' 'scaler__avg_temp' 'encoder__Area_Albania'
#  'encoder__Area_Algeria' 'encoder__Area_Angola' 'encoder__Area_Argentina'
#  'encoder__Area_Armenia' 'encoder__Area_Australia' 'encoder__Area_Austria'
#  'encoder__Area_Azerbaijan' 'encoder__Area_Bahamas'
#  'encoder__Area_Bahrain' 'encoder__Area_Bangladesh'
#  'encoder__Area_Belarus' 'encoder__Area_Belgium' 'encoder__Area_Botswana'
#  'encoder__Area_Brazil' 'encoder__Area_Bulgaria'
#  'encoder__Area_Burkina Faso' 'encoder__Area_Burundi'
#  'encoder__Area_Cameroon' 'encoder__Area_Canada'
#  'encoder__Area_Central African Republic' 'encoder__Area_Chile'
#  'encoder__Area_Colombia' 'encoder__Area_Croatia' 'encoder__Area_Denmark'
#  'encoder__Area_Dominican Republic' 'encoder__Area_Ecuador'
#  'encoder__Area_Egypt' 'encoder__Area_El Salvador' 'encoder__Area_Eritrea'
#  'encoder__Area_Estonia' 'encoder__Area_Finland' 'encoder__Area_France'
# ...

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error,r2_score

# %%
model = {
    'LinearRegression' : LinearRegression(),
    'Lasso': Lasso(),
    'Ridge': Ridge(),
    'DecisionTree': DecisionTreeRegressor(),
    'KNN': KNeighborsRegressor()
}

# %%
# Fit and transform the training data
X_train_dummy = preprocessor.fit_transform(X_train)

# Only transform the test data
X_test_dummy = preprocessor.transform(X_test)
# Initialize dictionaries
maeDict = {}
scoreDict = {}

for name, md in model.items():
    md.fit(X_train_dummy, Y_train)  # Use the transformed training data
    y_pred = md.predict(X_test_dummy)

    # Append to dictionaries
    maeDict[f"{name}"] = mean_absolute_error(Y_test, y_pred)
    scoreDict[f"{name}"] = r2_score(Y_test, y_pred)

import plotly.express as px
px.bar(x=maeDict.keys(),y=maeDict.values(),labels={"x":"Model","y":"MAE"})
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 255777530876.89844, tolerance: 12965348130.64751
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.bar(x=scoreDict.keys(),y=scoreDict.values(),labels={"x":"Model","y":"R2_Score"})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import numpy as np
X_train_dummy = np.hstack((X_train_dummy, np.zeros_like(X_train_dummy[0])))

# %%
import numpy as np
from scipy.sparse import hstack

# Extract the sparse matrix from the array
X_train_dummy_sparse = X_train_dummy[0]

# Add a column of zeros to the sparse matrix using scipy.sparse.hstack
X_train_dummy_sparse = hstack((X_train_dummy_sparse, np.zeros((X_train_dummy_sparse.shape[0], 1))))

# Similarly, add a column of zeros to X_test_dummy
X_test_dummy = hstack((X_test_dummy, np.zeros((X_test_dummy.shape[0], 1)))) # Make the number of features in the test set the same

dtr = DecisionTreeRegressor()
dtr.fit(X_train_dummy_sparse, Y_train)  # Use the modified sparse matrix for training
dtr.predict(X_test_dummy) # This should now work without error
# Out:
# array([41293., 22814., 25700., ..., 23600., 66667., 29886.])

# %%
df.columns
# Out:
# Index(['Area', 'Item', 'Year', 'hg/ha_yield', 'average_rain_fall_mm_per_year',
#        'pesticides_tonnes', 'avg_temp'],
#       dtype='object')

# %%
#predictive system

# %%
def prediction(year, rain, pesticides, temp, country, item,myModel):
    import pandas as pd  # Import pandas for DataFrame creation
    instance=pd.DataFrame([[year, rain, pesticides, temp, country, item]],
                              columns=['Year', 'average_rain_fall_mm_per_year',
                                       'pesticides_tonnes', 'avg_temp', 'Area', 'Item'])
    input_data = preprocessor.transform(instance)
    result = myModel.predict(input_data)
    return result  # Return the predicted value

# %%
transformedXTrain = preprocessor.fit_transform(X_train)
transformedXTest = preprocessor.fit_transform(X_test)
trainedModel=model['LinearRegression'].fit(transformedXTrain,Y_train)

# Call the prediction function with your input data
predicted_value = prediction(1990, 1485.0, 121.0, 16.37, 'Albania', 'Maize',trainedModel)

# Print the predicted value
print(predicted_value)
# Out:
# [20420.92629815]

# %%
import pickle
pickle.dump(dtr,open("dtr.pkl","wb"))
pickle.dump(preprocessor, open("preprocessor.pkl", "wb"))

# %%
preprocessor = ColumnTransformer(
         transformers=[
             ('num', StandardScaler(), numerical_features),
             ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
         ])

# %%
print(X_train['Area'].unique())
print(X_train['Item'].unique())
# Out:
# ['Colombia' 'Pakistan' 'Brazil' 'Canada' 'Italy' 'Japan' 'Ireland'
#  'Bangladesh' 'Chile' 'Australia' 'Indonesia' 'Mexico' 'Mauritania'
#  'New Zealand' 'India' 'Lebanon' 'Uganda' 'United Kingdom' 'Germany'
#  'Ecuador' 'Uruguay' 'South Africa' 'Rwanda' 'Latvia' 'Argentina'
#  'Romania' 'Nicaragua' 'Finland' 'Kazakhstan' 'Cameroon' 'Denmark' 'Nepal'
#  'Zimbabwe' 'Turkey' 'Honduras' 'Jamaica' 'El Salvador' 'Burkina Faso'
#  'France' 'Burundi' 'Papua New Guinea' 'Malawi' 'Egypt' 'Sri Lanka'
#  'Morocco' 'Peru' 'Guatemala' 'Slovenia' 'Mozambique' 'Guinea' 'Bahrain'
#  'Switzerland' 'Tajikistan' 'Spain' 'Namibia' 'Suriname' 'Hungary'
#  'Albania' 'Central African Republic' 'Niger' 'Greece' 'Mali' 'Kenya'
#  'Croatia' 'Iraq' 'Zambia' 'Angola' 'Haiti' 'Libya' 'Austria' 'Portugal'
#  'Senegal' 'Algeria' 'Belarus' 'Dominican Republic' 'Norway' 'Bulgaria'
#  'Guyana' 'Eritrea' 'Ghana' 'Azerbaijan' 'Madagascar' 'Mauritius'
# ...
